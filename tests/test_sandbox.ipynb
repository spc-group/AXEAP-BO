# %%
from axeap_bo import xes_calc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from axeap_bo import xes_calc
#
# File ~\Documents\.axeap_bo\Lib\site-packages\axeap_bo\xes_calc.py:3
#       1 import os
#       2 import numpy as np
# ----> 3 import cowan_config
#       4 import shutil
#       5 from datetime import datetime
#
# ModuleNotFoundError: No module named 'cowan_config'
