# %%
from axeap_bo import xes_calc

# %%
stick_x, stick_y, _, _ = xes_calc.gen_sticks("Ti", "2+")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 stick_x, stick_y, _, _ = xes_calc.gen_sticks("Ti", "2+")
#
# File ~\Documents\.axeap_bo\Lib\site-packages\axeap_bo\xes_calc.py:256, in gen_sticks(el, ox, fdd, fpd, gpd, soc, sov, tdq_g, tdq_e, dt_g, dt_e, ds_g, ds_e, m_g, m_e, em_start, em_end, G1, L1, L2, s_pt, norm)
#     253 bindEs = str(float(bindEs))
#     254 # fid_NFO.close()
# --> 256 if split:
#     257     fid1 = open(os.path.join(RunFileLocation,'Resources','template_split.plo'),'r')
#     258 else:
#
# UnboundLocalError: cannot access local variable 'split' where it is not associated with a value
